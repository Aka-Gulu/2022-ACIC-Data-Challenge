# %%
import pandas as pd
import numpy as np

# Assuming you load your data into DataFrame
# Replace 'path_to_predictions.csv' and 'path_to_truth.csv' with your actual file paths
df_predictions = pd.read_csv('final_results.csv')
df_truth = pd.read_csv('ACIC_estimand_truths.csv')

# Filter necessary rows
filtered_predictions = df_predictions[(df_predictions['level'].isna()) & (df_predictions['year'].isna())]
filtered_truth = df_truth[(df_truth['variable'] == 'Overall') & (df_truth['level'].isna()) & (df_truth['year'].isna())]

filtered_predictions
# Out:
#       variable  level  year       satt ci_method     lower90    upper90  \
# 2      Overall    NaN   NaN  -0.239052     basic  -14.914811  26.165198
# 5      Overall    NaN   NaN -13.469113     basic  -29.792565  11.325599
# 8      Overall    NaN   NaN -67.767011     basic -103.600481 -44.032105
# 11     Overall    NaN   NaN  36.127143     basic   -5.847755  69.242823
# 14     Overall    NaN   NaN  -8.672312     basic  -35.531012  17.619011
# ...        ...    ...   ...        ...       ...         ...        ...
# 10187  Overall    NaN   NaN  40.310830     basic   26.961916  67.119923
# 10190  Overall    NaN   NaN -13.360850     basic  -38.739107   5.117487
# 10193  Overall    NaN   NaN   1.405069     basic  -47.413589  42.824678
# 10196  Overall    NaN   NaN  32.214611     basic    3.228041  69.077893
# 10199  Overall    NaN   NaN   9.931821     basic  -12.883506  36.069645
#
#            bias  new_index
# 2     -0.363425          1
# 5      1.282670          2
# ...

# %%
# Merge on 'dataset_num' or 'new_index' from predictions matching with 'dataset_num' in truth
merged_data = pd.merge(filtered_predictions, filtered_truth, left_on='new_index', right_on='dataset.num', how='inner')
print(merged_data.shape)
# Calculate RMSE
rmse = np.sqrt(np.mean((merged_data['satt'] - merged_data['SATT'])**2))
print("The RMSE is:", rmse)
# Out:
# (3400, 19)
# The RMSE is: 21.51814940776224
